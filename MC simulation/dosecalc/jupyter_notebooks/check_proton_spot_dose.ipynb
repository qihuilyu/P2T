# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os, sys
sys.path.append('./webapi')
from sparse import load_sparse_data, sparse2dense
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-d1dba64629f4> in <module>
#       1 import os, sys
#       2 sys.path.append('./webapi')
# ----> 3 from sparse import load_sparse_data, sparse2dense
#
# ModuleNotFoundError: No module named 'sparse'

# %%
def load_spot_dose(spotfile):
    spot_dose = load_sparse_data(spotfile)
    dense_spot_dose = sparse2dense(*spot_dose)
    return dense_spot_dose
    
simdoc = db[DBCOLLECTIONS.SIMULATION].find_one({"_id": ObjectId("simulation_id"))
                                                geom_id =simdoc['geom_id']
# Out:
#   File "<ipython-input-6-377925868dae>", line 6
#     simdoc = db[DBCOLLECTIONS.SIMULATION].find_one({"_id": ObjectId("simulation_id"))
#                                                                                     ^
# SyntaxError: invalid syntax

# %%
root = "/home/shenglab6/MCDose/dosecalc/montecarlo/mc_data/1/results/run000/dose3d.bin"
spot_dose = load_spot_dose(root)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-058e8594ffb1> in <module>
#       1 root = "/home/shenglab6/MCDose/dosecalc/montecarlo/mc_data/1/results/run000/dose3d.bin"
# ----> 2 spot_dose = load_spot_dose(root)
#
# NameError: name 'load_spot_dose' is not defined

# %%
print(spot_dose.shape)
density_file = "/home/shenglab6/MCDose/dosecalc/montecarlo/mc_data/1/results/InputDensity.bin"
from utils import load_bin
density_arr = load_bin(density_file, size=(300,300,300))

# %%
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10,10), dpi=150)
ax = fig.add_subplot(1,1,1)
slice_sum = np.sum(spot_dose, axis=(1,2))
slice_idx = np.argmax(slice_sum)
ax.imshow(density_arr[slice_idx], cmap="gray")
ax.imshow(spot_dose[slice_idx], alpha=0.6)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-77b7b1fd6e5c> in <module>
#       3 fig = plt.figure(figsize=(10,10), dpi=150)
#       4 ax = fig.add_subplot(1,1,1)
# ----> 5 slice_sum = np.sum(spot_dose, axis=(1,2))
#       6 slice_idx = np.argmax(slice_sum)
#       7 ax.imshow(density_arr[slice_idx], cmap="gray")
#
# NameError: name 'spot_dose' is not defined
